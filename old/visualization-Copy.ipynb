# %% [markdown]
# ## Import libraries

# %%
import folium
import pandas as pd
import json
from numpy import median
from folium import Choropleth, Circle, Marker, Icon, Map
import ast

# %%
df = pd.read_csv('data/df_api.csv')

# %%
df.head()
# Out:
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1       Aviary               $19M                  USA                 NY
# 2  Gilt Groupe              $236M                  USA                 NY
# 3    99designs               $35M                  USA                 CA
# 4       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.749376         -73.996435  243 West 30th Street
# 2         40.747270         -73.980064       2 Park Ave Fl 4
# 3         37.795531        -122.400598       447 Battery St.
# 4         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1        11th Floor            10001
# 2               NaN       10016-5602
# 3         3rd Floor            94111
# 4         2nd Floor            94111
#
#                                           vegan_rest  num_vegan_rest
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...              10  \
# 1  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...              10
# 2  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...              10
# 3  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
# 4  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
#
#                                            preschool  num_preschool
# 0  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              3  \
# 1  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              2
# 2  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...              1
# 3  [{'fsq_id': '558a380a498e13330910aef6', 'categ...              1
# 4  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...              3
#
#                                            starbucks  num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8  \
# 1  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 2  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 3  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 4  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
#
#                                              airport  num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10  \
# 1  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 2  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 3  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 4  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
#
#                                                clubs  num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10  \
# 1  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 2  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 3  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 4  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
#
#    weighted_punct
# 0          824.98
# 1          821.40
# 2          732.10
# 3          699.97
# 4          607.15

# %%
df_subset = df[df['weighted_punct'] > 600]

# %%
df_subset['vegan_rest'] = df_subset['vegan_rest'].apply(ast.literal_eval)
# Out:
# C:\Users\Laura\AppData\Local\Temp\ipykernel_24796\3433824591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['vegan_rest'] = df_subset['vegan_rest'].apply(ast.literal_eval)

# %%
df_subset
# Out:
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1       Aviary               $19M                  USA                 NY
# 2  Gilt Groupe              $236M                  USA                 NY
# 3    99designs               $35M                  USA                 CA
# 4       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.749376         -73.996435  243 West 30th Street
# 2         40.747270         -73.980064       2 Park Ave Fl 4
# 3         37.795531        -122.400598       447 Battery St.
# 4         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1        11th Floor            10001
# 2               NaN       10016-5602
# 3         3rd Floor            94111
# 4         2nd Floor            94111
#
#                                           vegan_rest  num_vegan_rest
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...              10  \
# 1  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...              10
# 2  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...              10
# 3  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
# 4  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
#
#                                            preschool  num_preschool
# 0  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              3  \
# 1  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              2
# 2  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...              1
# 3  [{'fsq_id': '558a380a498e13330910aef6', 'categ...              1
# 4  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...              3
#
#                                            starbucks  num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8  \
# 1  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 2  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 3  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 4  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
#
#                                              airport  num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10  \
# 1  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 2  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 3  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 4  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
#
#                                                clubs  num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10  \
# 1  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 2  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 3  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 4  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
#
#    weighted_punct
# 0          824.98
# 1          821.40
# 2          732.10
# 3          699.97
# 4          607.15

# %%
#ast.literal_eval(df_subset['vegan_rest'][1])[0]

# %%
type(df_subset['vegan_rest'][0])
# Out:
# list

# %%
def pre_explode(x):
    new_list = []
    for i in df_subset['vegan_rest'][0]:
        lat = i["geocodes"]["main"]["latitude"]
        lon = i["geocodes"]["main"]["longitude"]
        new_list.append((lat, lon))
    return new_list

# %%
df_subset['vegan_rest_2'] = df_subset['vegan_rest'].apply(pre_explode)
df_subset
# Out:
# C:\Users\Laura\AppData\Local\Temp\ipykernel_24796\3247127576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['vegan_rest_2'] = df_subset['vegan_rest'].apply(pre_explode)
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1       Aviary               $19M                  USA                 NY
# 2  Gilt Groupe              $236M                  USA                 NY
# 3    99designs               $35M                  USA                 CA
# 4       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.749376         -73.996435  243 West 30th Street
# 2         40.747270         -73.980064       2 Park Ave Fl 4
# 3         37.795531        -122.400598       447 Battery St.
# 4         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1        11th Floor            10001
# 2               NaN       10016-5602
# 3         3rd Floor            94111
# 4         2nd Floor            94111
#
#                                           vegan_rest  ...
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...  \
# 1  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...
# 2  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...
# 3  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
# 4  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
#
#                                            preschool num_preschool
# 0  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             3  \
# 1  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             2
# 2  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...             1
# 3  [{'fsq_id': '558a380a498e13330910aef6', 'categ...             1
# 4  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...             3
#
#                                            starbucks num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...             8  \
# 1  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...            10
# 2  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...            10
# 3  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...             7
# 4  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...             3
#
#                                              airport num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...          10  \
# 1  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...          10
# 2  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...          10
# 3  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...           9
# 4  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...           3
#
#                                                clubs num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...        10  \
# 1  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...         8
# 2  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...         4
# 3  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...         7
# 4  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...         9
#
#    weighted_punct                                       vegan_rest_2
# 0          824.98  [(40.744946, -73.990249), (40.743323, -73.9943...
# 1          821.40  [(40.744946, -73.990249), (40.743323, -73.9943...
# 2          732.10  [(40.744946, -73.990249), (40.743323, -73.9943...
# 3          699.97  [(40.744946, -73.990249), (40.743323, -73.9943...
# 4          607.15  [(40.744946, -73.990249), (40.743323, -73.9943...
#
# [5 rows x 21 columns]

# %%
df_subset['vegan_rest_2'][0]
# Out:
# [(40.744946, -73.990249),
#  (40.743323, -73.994378),
#  (40.745153, -73.994538),
#  (40.746151, -73.997547),
#  (40.745543, -73.994073),
#  (40.745134, -73.995236),
#  (40.750153, -73.995215),
#  (40.747204, -73.996497),
#  (40.747313, -74.000432),
#  (40.74262, -73.996447)]

# %%
df_subset['vegan_rest_2'][0]
# Out:
# [(40.744946, -73.990249),
#  (40.743323, -73.994378),
#  (40.745153, -73.994538),
#  (40.746151, -73.997547),
#  (40.745543, -73.994073),
#  (40.745134, -73.995236),
#  (40.750153, -73.995215),
#  (40.747204, -73.996497),
#  (40.747313, -74.000432),
#  (40.74262, -73.996447)]

# %%
ast.literal_eval(df_subset['vegan_rest'][3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ast.literal_eval(df_subset['vegan_rest'][3])
#
# File ~\miniconda3\envs\ironhack\lib\ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File ~\miniconda3\envs\ironhack\lib\ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File ~\miniconda3\envs\ironhack\lib\ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# File ~\miniconda3\envs\ironhack\lib\ast.py:74, in literal_eval.<locals>._convert_num(node)
#      72 def _convert_num(node):
#      73     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 74         _raise_malformed_node(node)
#      75     return node.value
#
# File ~\miniconda3\envs\ironhack\lib\ast.py:71, in literal_eval.<locals>._raise_malformed_node(node)
#      69 if lno := getattr(node, 'lineno', None):
#      70     msg += f' on line {lno}'
# ---> 71 raise ValueError(msg + f': {node!r}')
#
# ValueError: malformed node or string: [{'fsq_id': '4b391baef964a520605625e3', 'categories': [{'id': 13099, 'name': 'Chinese Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_', 'suffix': '.png'}}, {'id': 13377, 'name': 'Vegan and Vegetarian Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_', 'suffix': '.png'}}], 'chains': [], 'distance': 396, 'geocodes': {'main': {'latitude': 37.795836, 'longitude': -122.405323}, 'roof': {'latitude': 37.795836, 'longitude': -122.405323}}, 'link': '/v3/places/4b391baef964a520605625e3', 'location': {'address': '839 Kearny St', 'census_block': '060750611011005', 'country': 'US', 'cross_street': 'at Washington St.', 'dma': 'San Francisco-Oakland-San Jose', 'formatted_address': '839 Kearny St (at Washington St.), San Francisco, CA 94108', 'locality': 'San Francisco', 'postcode': '94108', 'region': 'CA'}, 'name': 'Enjoy Vegetarian Restaurant', 'related_places': {}, 'timezone': 'America/Los_Angeles'}, {'fsq_id': '4570691ff964a5205c3e1fe3', 'categories': [{'id': 13177, 'name': 'Greek Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_', 'suffix': '.png'}}, {'id': 13302, 'name': 'Mediterranean Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}}], 'chains': [], 'distance': 171, 'geocodes': {'main': {'latitude': 37.797041, 'longitude': -122.399802}, 'roof': {'latitude': 37.797041, 'longitude': -122.399802}}, 'link': '/v3/places/4570691ff964a5205c3e1fe3', 'location': {'address': '200 Jackson St', 'census_block': '060750105001019', 'country': 'US', 'cross_street': 'at Front St', 'dma': 'San Francisco-Oakland-San Jose', 'formatted_address': '200 Jackson St (at Front St), San Francisco, CA 94111', 'locality': 'San Francisco', 'postcode': '94111', 'region': 'CA'}, 'name': 'Kokkari Estiatorio', 'related_places': {}, 'timezone': 'America/Los_Angeles'}, {'fsq_id': '4cd0a38e5b5ca35de6317df0', 'categories': [{'id': 13064, 'name': 'Pizzeria', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}}, {'id': 13236, 'name': 'Italian Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}}], 'chains': [], 'distance': 333, 'geocodes': {'main': {'latitude': 37.797485, 'longitude': -122.403413}, 'roof': {'latitude': 37.797485, 'longitude': -122.403413}}, 'link': '/v3/places/4cd0a38e5b5ca35de6317df0', 'location': {'address': '490 Pacific Ave', 'census_block': '060750106002007', 'country': 'US', 'cross_street': 'at Montgomery St', 'dma': 'San Francisco-Oakland-San Jose', 'formatted_address': '490 Pacific Ave (at Montgomery St), San Francisco, CA 94133', 'locality': 'San Francisco', 'postcode': '94133', 'region': 'CA'}, 'name': 'Cotogna', 'related_places': {}, 'timezone': 'America/Los_Angeles'}, {'fsq_id': '563d1b6ecd1073c835e14047', 'categories': [{'id': 13034, 'name': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': 13377, 'name': 'Vegan and Vegetarian Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_', 'suffix': '.png'}}], 'chains': [], 'distance': 437, 'geocodes': {'drop_off': {'latitude': 37.791606, 'longitude': -122.402537}, 'main': {'latitude': 37.791658, 'longitude': -122.402281}, 'roof': {'latitude': 37.791658, 'longitude': -122.402281}}, 'link': '/v3/places/563d1b6ecd1073c835e14047', 'location': {'address': '250 Montgomery St', 'census_block': '060750117002018', 'country': 'US', 'cross_street': 'Pine St.', 'dma': 'San Francisco-Oakland-San Jose', 'formatted_address': '250 Montgomery St (Pine St.), San Francisco, CA 94104', 'locality': 'San Francisco', 'postcode': '94104', 'region': 'CA'}, 'name': 'The Plant Cafe Organic', 'related_places': {}, 'timezone': 'America/Los_Angeles'}, {'fsq_id': '5d0a985b972c0d0023090738', 'categories': [{'id': 13006, 'name': 'Beer Bar', 'icon': { ...

# %%
p1_lat_NY, p1_lon_NY, p2_lat_NY, p2_lon_NY, p3_lat_NY, p3_lon_NY = df['offices_latitude'][0], df['offices_longitude'][0], df['offices_latitude'][1], df['offices_longitude'][1], df['offices_latitude'][2], df['offices_longitude'][2]

# %%
middle_lat_NY = median([p1_lat_NY, p2_lat_NY, p3_lat_NY])
middle_lon_NY = median([p1_lon_NY, p2_lon_NY, p3_lon_NY])

# %%
testmap_NY = folium.Map(location=[middle_lat_NY, middle_lon_NY], zoom_start=13)

# %%
folium.Circle(location=[p1_lat_NY, p1_lon_NY], popup='Point 1A', fill_color='#ff0000', radius=200, weight=2, color="#000000").add_to(testmap_NY)
folium.Circle(location=[p2_lat_NY, p2_lon_NY], popup='Point 1B', fill_color='#00ff00', radius=200, weight=2, color="#000000").add_to(testmap_NY)
folium.Circle(location=[p3_lat_NY, p3_lon_NY], popup='Point 1C', fill_color='#0000ff', radius=200, weight=2, color="#ffffff").add_to(testmap_NY)

# %%
display(testmap_NY)

# %%
for index, row in df.iterrows():
    
    all_together = {"location": [row["offices_latitude"], row["offices_longitude"]]}
            
    # 1. Check for the conditions of Festividad: to get the diferent Icon
    if row["num_vegan_rest"] != None:
        icon = Icon (
                icon = "laptop",
                prefix = "fa",
                color = "red",
                icon_color = "white")
        
    elif row["num_preschool"] != None:
        icon = Icon (
                icon = "moon-o",
                prefix = "fa",
                color = "white",
                icon_color = "black")
        
    elif row["num_starbucks"] != None:
        icon = Icon (
                icon = "cutlery",
                prefix = "fa",
                color = "green",
                icon_color = "white")
        
    elif row["num_airport"] != None:
        icon = Icon (
                icon = "cutlery",
                prefix = "fa",
                color = "green",
                icon_color = "white")
        
    elif row["num_clubs"] != None:
        icon = Icon (
                icon = "cutlery",
                prefix = "fa",
                color = "green",
                icon_color = "white")
    
    # 2. With the icon: I pass that to the Marker

    new_marker = Marker(**all_together, icon = icon)
    
    # 3. Add a Marker per row
    
    new_marker.add_to(testmap_NY)

testmap_NY

# %%
for index, row in df.iterrows():
    
    all_together = {"location": [row["offices_latitude"], row["offices_longitude"]]}
            
    # 1. Check for the conditions of Festividad: to get the diferent Icon
    if row["num_vegan_rest"] != None:
        icon = Icon (
                icon = "laptop",
                prefix = "fa",
                color = "red",
                icon_color = "white")
      
    # 2. With the icon: I pass that to the Marker

    new_marker = Marker(**all_together, icon = icon)
    
    # 3. Add a Marker per row
    
    new_marker.add_to(testmap_NY)

testmap_NY
