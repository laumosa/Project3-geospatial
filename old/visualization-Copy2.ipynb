# %% [markdown]
# ## Import libraries

# %%
import folium
import pandas as pd
import json
from numpy import median
from folium import Choropleth, Circle, Marker, Icon, Map
import ast

# %%
df = pd.read_csv('data/df_api.csv')

# %%
df.head()
# Out:
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1       Aviary               $19M                  USA                 NY
# 2  Gilt Groupe              $236M                  USA                 NY
# 3    99designs               $35M                  USA                 CA
# 4       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.749376         -73.996435  243 West 30th Street
# 2         40.747270         -73.980064       2 Park Ave Fl 4
# 3         37.795531        -122.400598       447 Battery St.
# 4         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1        11th Floor            10001
# 2               NaN       10016-5602
# 3         3rd Floor            94111
# 4         2nd Floor            94111
#
#                                           vegan_rest  num_vegan_rest
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...              10  \
# 1  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...              10
# 2  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...              10
# 3  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
# 4  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
#
#                                            preschool  num_preschool
# 0  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              3  \
# 1  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              2
# 2  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...              1
# 3  [{'fsq_id': '558a380a498e13330910aef6', 'categ...              1
# 4  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...              3
#
#                                            starbucks  num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8  \
# 1  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 2  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 3  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 4  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
#
#                                              airport  num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10  \
# 1  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 2  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 3  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 4  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
#
#                                                clubs  num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10  \
# 1  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 2  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 3  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 4  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
#
#    weighted_punct
# 0          824.98
# 1          821.40
# 2          732.10
# 3          699.97
# 4          607.15

# %%
df_subset = df[df['weighted_punct'] > 600]

# %%
df_subset['vegan_rest'] = df_subset['vegan_rest'].apply(ast.literal_eval)
# Out:
# C:\Users\Laura\AppData\Local\Temp\ipykernel_26508\3433824591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['vegan_rest'] = df_subset['vegan_rest'].apply(ast.literal_eval)

# %%
df_subset
# Out:
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1       Aviary               $19M                  USA                 NY
# 2  Gilt Groupe              $236M                  USA                 NY
# 3    99designs               $35M                  USA                 CA
# 4       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.749376         -73.996435  243 West 30th Street
# 2         40.747270         -73.980064       2 Park Ave Fl 4
# 3         37.795531        -122.400598       447 Battery St.
# 4         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1        11th Floor            10001
# 2               NaN       10016-5602
# 3         3rd Floor            94111
# 4         2nd Floor            94111
#
#                                           vegan_rest  num_vegan_rest
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...              10  \
# 1  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...              10
# 2  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...              10
# 3  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
# 4  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
#
#                                            preschool  num_preschool
# 0  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              3  \
# 1  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              2
# 2  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...              1
# 3  [{'fsq_id': '558a380a498e13330910aef6', 'categ...              1
# 4  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...              3
#
#                                            starbucks  num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8  \
# 1  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 2  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 3  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 4  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
#
#                                              airport  num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10  \
# 1  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 2  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 3  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 4  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
#
#                                                clubs  num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10  \
# 1  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 2  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 3  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 4  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
#
#    weighted_punct
# 0          824.98
# 1          821.40
# 2          732.10
# 3          699.97
# 4          607.15

# %%
#ast.literal_eval(df_subset['vegan_rest'][1])[0]

# %%
type(df_subset['vegan_rest'][0])
# Out:
# list

# %%
def pre_explode(x):
    new_dict = {}
    for i in df_subset['vegan_rest'][0]:
        lat = i["geocodes"]["main"]["latitude"]
        lon = i["geocodes"]["main"]["longitude"]
        new_dict = {"lat":lat, "lon":lon}
    return new_dict

# %%
df_subset['vegan_rest_2'] = df_subset['vegan_rest'].apply(pre_explode)
df_subset
# Out:
# C:\Users\Laura\AppData\Local\Temp\ipykernel_26508\3247127576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['vegan_rest_2'] = df_subset['vegan_rest'].apply(pre_explode)
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1       Aviary               $19M                  USA                 NY
# 2  Gilt Groupe              $236M                  USA                 NY
# 3    99designs               $35M                  USA                 CA
# 4       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.749376         -73.996435  243 West 30th Street
# 2         40.747270         -73.980064       2 Park Ave Fl 4
# 3         37.795531        -122.400598       447 Battery St.
# 4         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1        11th Floor            10001
# 2               NaN       10016-5602
# 3         3rd Floor            94111
# 4         2nd Floor            94111
#
#                                           vegan_rest  ...
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...  \
# 1  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...
# 2  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...
# 3  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
# 4  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
#
#                                            preschool num_preschool
# 0  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             3  \
# 1  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             2
# 2  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...             1
# 3  [{'fsq_id': '558a380a498e13330910aef6', 'categ...             1
# 4  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...             3
#
#                                            starbucks num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...             8  \
# 1  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...            10
# 2  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...            10
# 3  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...             7
# 4  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...             3
#
#                                              airport num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...          10  \
# 1  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...          10
# 2  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...          10
# 3  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...           9
# 4  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...           3
#
#                                                clubs num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...        10  \
# 1  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...         8
# 2  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...         4
# 3  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...         7
# 4  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...         9
#
#    weighted_punct                          vegan_rest_2
# 0          824.98  {'lat': 40.74262, 'lon': -73.996447}
# 1          821.40  {'lat': 40.74262, 'lon': -73.996447}
# 2          732.10  {'lat': 40.74262, 'lon': -73.996447}
# 3          699.97  {'lat': 40.74262, 'lon': -73.996447}
# 4          607.15  {'lat': 40.74262, 'lon': -73.996447}
#
# [5 rows x 21 columns]

# %%
df_subset['vegan_rest_2'][0]
# Out:
# {'lat': 40.74262, 'lon': -73.996447}

# %%
df_subset = df_subset.explode('vegan_rest_2')
df_subset = df_subset.reset_index(drop=True)

# %%
df_subset
# Out:
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1  Netbiscuits               $27M                  USA                 NY
# 2       Aviary               $19M                  USA                 NY
# 3       Aviary               $19M                  USA                 NY
# 4  Gilt Groupe              $236M                  USA                 NY
# 5  Gilt Groupe              $236M                  USA                 NY
# 6    99designs               $35M                  USA                 CA
# 7    99designs               $35M                  USA                 CA
# 8       Minted             $52.7M                  USA                 CA
# 9       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.746754         -73.995323             7th Floor
# 2         40.749376         -73.996435  243 West 30th Street
# 3         40.749376         -73.996435  243 West 30th Street
# 4         40.747270         -73.980064       2 Park Ave Fl 4
# 5         40.747270         -73.980064       2 Park Ave Fl 4
# 6         37.795531        -122.400598       447 Battery St.
# 7         37.795531        -122.400598       447 Battery St.
# 8         37.797435        -122.403175      747 Front Street
# 9         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1   275 Seventh Ave            10001
# 2        11th Floor            10001
# 3        11th Floor            10001
# 4               NaN       10016-5602
# 5               NaN       10016-5602
# 6         3rd Floor            94111
# 7         3rd Floor            94111
# 8         2nd Floor            94111
# 9         2nd Floor            94111
#
#                                           vegan_rest  ...
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...  \
# 1  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...
# 2  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...
# 3  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...
# 4  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...
# 5  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...
# 6  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
# 7  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
# 8  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
# 9  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
#
#                                            preschool num_preschool
# 0  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             3  \
# 1  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             3
# 2  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             2
# 3  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             2
# 4  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...             1
# 5  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...             1
# 6  [{'fsq_id': '558a380a498e13330910aef6', 'categ...             1
# 7  [{'fsq_id': '558a380a498e13330910aef6', 'categ...             1
# 8  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...             3
# 9  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...             3
#
#                                            starbucks num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...             8  \
# 1  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...             8
# 2  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...            10
# 3  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...            10
# 4  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...            10
# 5  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...            10
# 6  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...             7
# 7  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...             7
# 8  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...             3
# 9  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...             3
#
#                                              airport num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...          10  \
# 1  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...          10
# 2  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...          10
# 3  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...          10
# 4  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...          10
# 5  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...          10
# 6  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...           9
# 7  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...           9
# 8  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...           3
# 9  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...           3
#
#                                                clubs num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...        10  \
# 1  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...        10
# 2  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...         8
# 3  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...         8
# 4  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...         4
# 5  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...         4
# 6  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...         7
# 7  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...         7
# 8  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...         9
# 9  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...         9
#
#    weighted_punct  vegan_rest_2
# 0          824.98           lat
# 1          824.98           lon
# 2          821.40           lat
# 3          821.40           lon
# 4          732.10           lat
# 5          732.10           lon
# 6          699.97           lat
# 7          699.97           lon
# 8          607.15           lat
# 9          607.15           lon
#
# [10 rows x 21 columns]

# %%
df_subset
# Out:
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1  Netbiscuits               $27M                  USA                 NY
# 2       Aviary               $19M                  USA                 NY
# 3       Aviary               $19M                  USA                 NY
# 4  Gilt Groupe              $236M                  USA                 NY
# 5  Gilt Groupe              $236M                  USA                 NY
# 6    99designs               $35M                  USA                 CA
# 7    99designs               $35M                  USA                 CA
# 8       Minted             $52.7M                  USA                 CA
# 9       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.746754         -73.995323             7th Floor
# 2         40.749376         -73.996435  243 West 30th Street
# 3         40.749376         -73.996435  243 West 30th Street
# 4         40.747270         -73.980064       2 Park Ave Fl 4
# 5         40.747270         -73.980064       2 Park Ave Fl 4
# 6         37.795531        -122.400598       447 Battery St.
# 7         37.795531        -122.400598       447 Battery St.
# 8         37.797435        -122.403175      747 Front Street
# 9         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1   275 Seventh Ave            10001
# 2        11th Floor            10001
# 3        11th Floor            10001
# 4               NaN       10016-5602
# 5               NaN       10016-5602
# 6         3rd Floor            94111
# 7         3rd Floor            94111
# 8         2nd Floor            94111
# 9         2nd Floor            94111
#
#                                           vegan_rest  ...
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...  \
# 1  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...
# 2  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...
# 3  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...
# 4  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...
# 5  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...
# 6  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
# 7  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
# 8  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
# 9  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...
#
#                                            preschool num_preschool
# 0  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             3  \
# 1  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             3
# 2  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             2
# 3  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...             2
# 4  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...             1
# 5  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...             1
# 6  [{'fsq_id': '558a380a498e13330910aef6', 'categ...             1
# 7  [{'fsq_id': '558a380a498e13330910aef6', 'categ...             1
# 8  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...             3
# 9  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...             3
#
#                                            starbucks num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...             8  \
# 1  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...             8
# 2  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...            10
# 3  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...            10
# 4  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...            10
# 5  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...            10
# 6  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...             7
# 7  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...             7
# 8  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...             3
# 9  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...             3
#
#                                              airport num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...          10  \
# 1  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...          10
# 2  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...          10
# 3  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...          10
# 4  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...          10
# 5  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...          10
# 6  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...           9
# 7  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...           9
# 8  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...           3
# 9  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...           3
#
#                                                clubs num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...        10  \
# 1  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...        10
# 2  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...         8
# 3  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...         8
# 4  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...         4
# 5  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...         4
# 6  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...         7
# 7  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...         7
# 8  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...         9
# 9  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...         9
#
#    weighted_punct  vegan_rest_2
# 0          824.98           lat
# 1          824.98           lon
# 2          821.40           lat
# 3          821.40           lon
# 4          732.10           lat
# 5          732.10           lon
# 6          699.97           lat
# 7          699.97           lon
# 8          607.15           lat
# 9          607.15           lon
#
# [10 rows x 21 columns]

# %%
df_subset['vegan_rest_2'][0]
# Out:
# 'lat'

# %%
ast.literal_eval(df_subset['vegan_rest'][3])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 ast.literal_eval(df_subset['vegan_rest'][3])
#
# File ~\miniconda3\envs\ironhack\lib\ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File ~\miniconda3\envs\ironhack\lib\ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File ~\miniconda3\envs\ironhack\lib\ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# File ~\miniconda3\envs\ironhack\lib\ast.py:74, in literal_eval.<locals>._convert_num(node)
#      72 def _convert_num(node):
#      73     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 74         _raise_malformed_node(node)
#      75     return node.value
#
# File ~\miniconda3\envs\ironhack\lib\ast.py:71, in literal_eval.<locals>._raise_malformed_node(node)
#      69 if lno := getattr(node, 'lineno', None):
#      70     msg += f' on line {lno}'
# ---> 71 raise ValueError(msg + f': {node!r}')
#
# ValueError: malformed node or string: [{'fsq_id': '5f161e6f978e663e91ab7155', 'categories': [{'id': 13003, 'name': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}}, {'id': 13303, 'name': 'Mexican Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_', 'suffix': '.png'}}], 'chains': [], 'distance': 433, 'geocodes': {'main': {'latitude': 40.752566, 'longitude': -73.999722}, 'roof': {'latitude': 40.752566, 'longitude': -73.999722}}, 'link': '/v3/places/5f161e6f978e663e91ab7155', 'location': {'address': '450 W 33rd St', 'census_block': '360610103001003', 'country': 'US', 'cross_street': '', 'dma': 'New York', 'formatted_address': '450 W 33rd St, New York, NY 10001', 'locality': 'New York', 'postcode': '10001', 'region': 'NY'}, 'name': 'Jajaja Plantas Mexicana', 'related_places': {'parent': {'fsq_id': '5f0f9256e0ccd447d4424216', 'name': 'Whole Foods'}}, 'timezone': 'America/New_York'}, {'fsq_id': '4a639f9ff964a52077c51fe3', 'categories': [{'id': 13064, 'name': 'Pizzeria', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_', 'suffix': '.png'}}], 'chains': [], 'distance': 147, 'geocodes': {'drop_off': {'latitude': 40.750094, 'longitude': -73.995135}, 'main': {'latitude': 40.750153, 'longitude': -73.995215}, 'roof': {'latitude': 40.750153, 'longitude': -73.995215}}, 'link': '/v3/places/4a639f9ff964a52077c51fe3', 'location': {'address': '413 8th Ave', 'address_extended': 'btwn W 30th  W 31st St', 'census_block': '360610103001012', 'country': 'US', 'cross_street': 'btwn W 30th & W 31st St', 'dma': 'New York', 'formatted_address': '413 8th Ave (btwn W 30th & W 31st St), New York, NY 10001', 'locality': 'New York', 'postcode': '10001', 'region': 'NY'}, 'name': 'NY Pizza Suprema', 'related_places': {'children': []}, 'timezone': 'America/New_York'}, {'fsq_id': '49c406a8f964a5208d561fe3', 'categories': [{'id': 13001, 'name': 'Bagel Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_', 'suffix': '.png'}}, {'id': 13068, 'name': 'American Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}, {'id': 13039, 'name': 'Deli', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_', 'suffix': '.png'}}], 'chains': [], 'distance': 377, 'geocodes': {'main': {'latitude': 40.746151, 'longitude': -73.997547}, 'roof': {'latitude': 40.746151, 'longitude': -73.997547}}, 'link': '/v3/places/49c406a8f964a5208d561fe3', 'location': {'address': '286 8th Ave', 'address_extended': 'Frnt 1', 'census_block': '360610091001000', 'country': 'US', 'cross_street': 'btwn W 24th & W 25th St', 'dma': 'New York', 'formatted_address': '286 8th Ave (btwn W 24th & W 25th St), New York, NY 10001', 'locality': 'New York', 'postcode': '10001', 'region': 'NY'}, 'name': 'Brooklyn Bagel & Coffee Company', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '59ca57dd3d47910ad148e668', 'categories': [{'id': 13032, 'name': 'Cafes, Coffee, and Tea Houses', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'chains': [], 'distance': 361, 'geocodes': {'main': {'latitude': 40.752209, 'longitude': -73.998965}, 'roof': {'latitude': 40.752209, 'longitude': -73.998965}}, 'link': '/v3/places/59ca57dd3d47910ad148e668', 'location': {'address': '435 W 31st St', 'census_block': '360610103001009', 'country': 'US', 'cross_street': 'btwn 9th & Dyer Ave', 'dma': 'New York', 'formatted_address': '435 W 31st St (btwn 9th & Dyer Ave), New York, NY 10001', 'locality': 'New York', 'postcode': '10001', 'region': 'NY'}, 'name': 'Bluestone Lane Manhattan West Café', 'related_places': {'parent': {'fsq_id': '58c46579110d0304a1ae28ba', 'name': 'The Eugene Apartments'}}, 'timezone': 'America/New_York'}, {'fsq_id': '4f61235ce4b0d7325f17c638', 'categories': [{'id': 13002, 'name': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', ' ...

# %%
p1_lat_NY, p1_lon_NY, p2_lat_NY, p2_lon_NY, p3_lat_NY, p3_lon_NY = df['offices_latitude'][0], df['offices_longitude'][0], df['offices_latitude'][1], df['offices_longitude'][1], df['offices_latitude'][2], df['offices_longitude'][2]

# %%
middle_lat_NY = median([p1_lat_NY, p2_lat_NY, p3_lat_NY])
middle_lon_NY = median([p1_lon_NY, p2_lon_NY, p3_lon_NY])

# %%
testmap_NY = folium.Map(location=[middle_lat_NY, middle_lon_NY], zoom_start=13)

# %%
folium.Circle(location=[p1_lat_NY, p1_lon_NY], popup='Point 1A', fill_color='#ff0000', radius=200, weight=2, color="#000000").add_to(testmap_NY)
folium.Circle(location=[p2_lat_NY, p2_lon_NY], popup='Point 1B', fill_color='#00ff00', radius=200, weight=2, color="#000000").add_to(testmap_NY)
folium.Circle(location=[p3_lat_NY, p3_lon_NY], popup='Point 1C', fill_color='#0000ff', radius=200, weight=2, color="#ffffff").add_to(testmap_NY)

# %%
display(testmap_NY)

# %%
for index, row in df.iterrows():
    
    all_together = {"location": [row["offices_latitude"], row["offices_longitude"]]}
            
    # 1. Check for the conditions of Festividad: to get the diferent Icon
    if row["num_vegan_rest"] != None:
        icon = Icon (
                icon = "laptop",
                prefix = "fa",
                color = "red",
                icon_color = "white")
        
    elif row["num_preschool"] != None:
        icon = Icon (
                icon = "moon-o",
                prefix = "fa",
                color = "white",
                icon_color = "black")
        
    elif row["num_starbucks"] != None:
        icon = Icon (
                icon = "cutlery",
                prefix = "fa",
                color = "green",
                icon_color = "white")
        
    elif row["num_airport"] != None:
        icon = Icon (
                icon = "cutlery",
                prefix = "fa",
                color = "green",
                icon_color = "white")
        
    elif row["num_clubs"] != None:
        icon = Icon (
                icon = "cutlery",
                prefix = "fa",
                color = "green",
                icon_color = "white")
    
    # 2. With the icon: I pass that to the Marker

    new_marker = Marker(**all_together, icon = icon)
    
    # 3. Add a Marker per row
    
    new_marker.add_to(testmap_NY)

testmap_NY

# %%
for index, row in df.iterrows():
    
    all_together = {"location": [row["offices_latitude"], row["offices_longitude"]]}
            
    # 1. Check for the conditions of Festividad: to get the diferent Icon
    if row["num_vegan_rest"] != None:
        icon = Icon (
                icon = "laptop",
                prefix = "fa",
                color = "red",
                icon_color = "white")
      
    # 2. With the icon: I pass that to the Marker

    new_marker = Marker(**all_together, icon = icon)
    
    # 3. Add a Marker per row
    
    new_marker.add_to(testmap_NY)

testmap_NY
