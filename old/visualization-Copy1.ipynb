# %% [markdown]
# ## Import libraries

# %%
import folium
import pandas as pd
import json
from numpy import median
from folium import Choropleth, Circle, Marker, Icon, Map
import ast

# %%
df = pd.read_csv('data/df_api.csv')

# %%
df.head()
# Out:
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1       Aviary               $19M                  USA                 NY
# 2  Gilt Groupe              $236M                  USA                 NY
# 3    99designs               $35M                  USA                 CA
# 4       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.749376         -73.996435  243 West 30th Street
# 2         40.747270         -73.980064       2 Park Ave Fl 4
# 3         37.795531        -122.400598       447 Battery St.
# 4         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1        11th Floor            10001
# 2               NaN       10016-5602
# 3         3rd Floor            94111
# 4         2nd Floor            94111
#
#                                           vegan_rest  num_vegan_rest
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...              10  \
# 1  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...              10
# 2  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...              10
# 3  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
# 4  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
#
#                                            preschool  num_preschool
# 0  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              3  \
# 1  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              2
# 2  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...              1
# 3  [{'fsq_id': '558a380a498e13330910aef6', 'categ...              1
# 4  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...              3
#
#                                            starbucks  num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8  \
# 1  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 2  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 3  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 4  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
#
#                                              airport  num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10  \
# 1  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 2  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 3  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 4  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
#
#                                                clubs  num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10  \
# 1  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 2  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 3  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 4  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
#
#    weighted_punct
# 0          824.98
# 1          821.40
# 2          732.10
# 3          699.97
# 4          607.15

# %%
df_subset = df[df['weighted_punct'] > 600]

# %%
df_subset['vegan_rest'] = df_subset['vegan_rest'].apply(ast.literal_eval)
# Out:
# C:\Users\Laura\AppData\Local\Temp\ipykernel_4552\3433824591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['vegan_rest'] = df_subset['vegan_rest'].apply(ast.literal_eval)

# %%
df_subset
# Out:
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1       Aviary               $19M                  USA                 NY
# 2  Gilt Groupe              $236M                  USA                 NY
# 3    99designs               $35M                  USA                 CA
# 4       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.749376         -73.996435  243 West 30th Street
# 2         40.747270         -73.980064       2 Park Ave Fl 4
# 3         37.795531        -122.400598       447 Battery St.
# 4         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1        11th Floor            10001
# 2               NaN       10016-5602
# 3         3rd Floor            94111
# 4         2nd Floor            94111
#
#                                           vegan_rest  num_vegan_rest
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...              10  \
# 1  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...              10
# 2  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...              10
# 3  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
# 4  [{'fsq_id': '4b391baef964a520605625e3', 'categ...              10
#
#                                            preschool  num_preschool
# 0  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              3  \
# 1  [{'fsq_id': '4d370251e4b4a09380322936', 'categ...              2
# 2  [{'fsq_id': '52712a6911d25f0e0dfa94cb', 'categ...              1
# 3  [{'fsq_id': '558a380a498e13330910aef6', 'categ...              1
# 4  [{'fsq_id': '5cc0a9cac0c0840025deceea', 'categ...              3
#
#                                            starbucks  num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8  \
# 1  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 2  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 3  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 4  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
#
#                                              airport  num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10  \
# 1  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 2  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 3  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 4  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
#
#                                                clubs  num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10  \
# 1  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 2  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 3  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 4  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
#
#    weighted_punct
# 0          824.98
# 1          821.40
# 2          732.10
# 3          699.97
# 4          607.15

# %%
#ast.literal_eval(df_subset['vegan_rest'][1])[0]

# %%
type(df_subset['vegan_rest'][0])
# Out:
# list

# %%
def pre_explode_lat(x):
    new_list = []
    for i in df_subset['vegan_rest'][0]:
        lat = i["geocodes"]["main"]["latitude"]
        new_list.append(lat)
    return new_list

# %%
def pre_explode_lon(x):
    new_list = []
    for i in df_subset['vegan_rest'][0]:
        lon = i["geocodes"]["main"]["longitude"]
        new_list.append(lon)
    return new_list

# %%
df_subset['vegan_rest_lat'] = df_subset['vegan_rest'].apply(pre_explode_lat)
df_subset['vegan_rest_lon'] = df_subset['vegan_rest'].apply(pre_explode_lon)
df_subset
# Out:
# C:\Users\Laura\AppData\Local\Temp\ipykernel_4552\2475285239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['vegan_rest_lat'] = df_subset['vegan_rest'].apply(pre_explode_lat)
# C:\Users\Laura\AppData\Local\Temp\ipykernel_4552\2475285239.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['vegan_rest_lon'] = df_subset['vegan_rest'].apply(pre_explode_lon)
#           name total_money_raised offices_country_code offices_state_code
# 0  Netbiscuits               $27M                  USA                 NY  \
# 1       Aviary               $19M                  USA                 NY
# 2  Gilt Groupe              $236M                  USA                 NY
# 3    99designs               $35M                  USA                 CA
# 4       Minted             $52.7M                  USA                 CA
#
#    offices_latitude  offices_longitude     offices_address_1
# 0         40.746754         -73.995323             7th Floor  \
# 1         40.749376         -73.996435  243 West 30th Street
# 2         40.747270         -73.980064       2 Park Ave Fl 4
# 3         37.795531        -122.400598       447 Battery St.
# 4         37.797435        -122.403175      747 Front Street
#
#   offices_address_2 offices_zip_code
# 0   275 Seventh Ave            10001  \
# 1        11th Floor            10001
# 2               NaN       10016-5602
# 3         3rd Floor            94111
# 4         2nd Floor            94111
#
#                                           vegan_rest  ...  num_preschool
# 0  [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3  \
# 1  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 2  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 3  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 4  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
#
#                                            starbucks  num_starbucks
# 0  [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8  \
# 1  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 2  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 3  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 4  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
#
#                                              airport  num_airport
# 0  [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10  \
# 1  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 2  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 3  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 4  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
#
#                                                clubs  num_clubs
# 0  [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10  \
# 1  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 2  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 3  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 4  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
#
#   weighted_punct                                     vegan_rest_lat
# 0         824.98  [40.744946, 40.743323, 40.745153, 40.746151, 4...  \
# 1         821.40  [40.744946, 40.743323, 40.745153, 40.746151, 4...
# 2         732.10  [40.744946, 40.743323, 40.745153, 40.746151, 4...
# 3         699.97  [40.744946, 40.743323, 40.745153, 40.746151, 4...
# 4         607.15  [40.744946, 40.743323, 40.745153, 40.746151, 4...
#
#                                       vegan_rest_lon
# 0  [-73.990249, -73.994378, -73.994538, -73.99754...
# 1  [-73.990249, -73.994378, -73.994538, -73.99754...
# 2  [-73.990249, -73.994378, -73.994538, -73.99754...
# 3  [-73.990249, -73.994378, -73.994538, -73.99754...
# 4  [-73.990249, -73.994378, -73.994538, -73.99754...
#
# [5 rows x 22 columns]

# %%
df_subset = df_subset.explode(['vegan_rest_lat', 'vegan_rest_lon'])
df_subset = df_subset.reset_index(drop=True)

# %%
df_subset
# Out:
#            name total_money_raised offices_country_code offices_state_code
# 0   Netbiscuits               $27M                  USA                 NY  \
# 1   Netbiscuits               $27M                  USA                 NY
# 2   Netbiscuits               $27M                  USA                 NY
# 3   Netbiscuits               $27M                  USA                 NY
# 4   Netbiscuits               $27M                  USA                 NY
# 5   Netbiscuits               $27M                  USA                 NY
# 6   Netbiscuits               $27M                  USA                 NY
# 7   Netbiscuits               $27M                  USA                 NY
# 8   Netbiscuits               $27M                  USA                 NY
# 9   Netbiscuits               $27M                  USA                 NY
# 10       Aviary               $19M                  USA                 NY
# 11       Aviary               $19M                  USA                 NY
# 12       Aviary               $19M                  USA                 NY
# 13       Aviary               $19M                  USA                 NY
# 14       Aviary               $19M                  USA                 NY
# 15       Aviary               $19M                  USA                 NY
# 16       Aviary               $19M                  USA                 NY
# 17       Aviary               $19M                  USA                 NY
# 18       Aviary               $19M                  USA                 NY
# 19       Aviary               $19M                  USA                 NY
# 20  Gilt Groupe              $236M                  USA                 NY
# 21  Gilt Groupe              $236M                  USA                 NY
# 22  Gilt Groupe              $236M                  USA                 NY
# 23  Gilt Groupe              $236M                  USA                 NY
# 24  Gilt Groupe              $236M                  USA                 NY
# 25  Gilt Groupe              $236M                  USA                 NY
# 26  Gilt Groupe              $236M                  USA                 NY
# 27  Gilt Groupe              $236M                  USA                 NY
# 28  Gilt Groupe              $236M                  USA                 NY
# 29  Gilt Groupe              $236M                  USA                 NY
# 30    99designs               $35M                  USA                 CA
# 31    99designs               $35M                  USA                 CA
# 32    99designs               $35M                  USA                 CA
# 33    99designs               $35M                  USA                 CA
# 34    99designs               $35M                  USA                 CA
# 35    99designs               $35M                  USA                 CA
# 36    99designs               $35M                  USA                 CA
# 37    99designs               $35M                  USA                 CA
# 38    99designs               $35M                  USA                 CA
# 39    99designs               $35M                  USA                 CA
# 40       Minted             $52.7M                  USA                 CA
# 41       Minted             $52.7M                  USA                 CA
# 42       Minted             $52.7M                  USA                 CA
# 43       Minted             $52.7M                  USA                 CA
# 44       Minted             $52.7M                  USA                 CA
# 45       Minted             $52.7M                  USA                 CA
# 46       Minted             $52.7M                  USA                 CA
# 47       Minted             $52.7M                  USA                 CA
# 48       Minted             $52.7M                  USA                 CA
# 49       Minted             $52.7M                  USA                 CA
#
#     offices_latitude  offices_longitude     offices_address_1
# 0          40.746754         -73.995323             7th Floor  \
# 1          40.746754         -73.995323             7th Floor
# 2          40.746754         -73.995323             7th Floor
# 3          40.746754         -73.995323             7th Floor
# 4          40.746754         -73.995323             7th Floor
# 5          40.746754         -73.995323             7th Floor
# 6          40.746754         -73.995323             7th Floor
# 7          40.746754         -73.995323             7th Floor
# 8          40.746754         -73.995323             7th Floor
# 9          40.746754         -73.995323             7th Floor
# 10         40.749376         -73.996435  243 West 30th Street
# 11         40.749376         -73.996435  243 West 30th Street
# 12         40.749376         -73.996435  243 West 30th Street
# 13         40.749376         -73.996435  243 West 30th Street
# 14         40.749376         -73.996435  243 West 30th Street
# 15         40.749376         -73.996435  243 West 30th Street
# 16         40.749376         -73.996435  243 West 30th Street
# 17         40.749376         -73.996435  243 West 30th Street
# 18         40.749376         -73.996435  243 West 30th Street
# 19         40.749376         -73.996435  243 West 30th Street
# 20         40.747270         -73.980064       2 Park Ave Fl 4
# 21         40.747270         -73.980064       2 Park Ave Fl 4
# 22         40.747270         -73.980064       2 Park Ave Fl 4
# 23         40.747270         -73.980064       2 Park Ave Fl 4
# 24         40.747270         -73.980064       2 Park Ave Fl 4
# 25         40.747270         -73.980064       2 Park Ave Fl 4
# 26         40.747270         -73.980064       2 Park Ave Fl 4
# 27         40.747270         -73.980064       2 Park Ave Fl 4
# 28         40.747270         -73.980064       2 Park Ave Fl 4
# 29         40.747270         -73.980064       2 Park Ave Fl 4
# 30         37.795531        -122.400598       447 Battery St.
# 31         37.795531        -122.400598       447 Battery St.
# 32         37.795531        -122.400598       447 Battery St.
# 33         37.795531        -122.400598       447 Battery St.
# 34         37.795531        -122.400598       447 Battery St.
# 35         37.795531        -122.400598       447 Battery St.
# 36         37.795531        -122.400598       447 Battery St.
# 37         37.795531        -122.400598       447 Battery St.
# 38         37.795531        -122.400598       447 Battery St.
# 39         37.795531        -122.400598       447 Battery St.
# 40         37.797435        -122.403175      747 Front Street
# 41         37.797435        -122.403175      747 Front Street
# 42         37.797435        -122.403175      747 Front Street
# 43         37.797435        -122.403175      747 Front Street
# 44         37.797435        -122.403175      747 Front Street
# 45         37.797435        -122.403175      747 Front Street
# 46         37.797435        -122.403175      747 Front Street
# 47         37.797435        -122.403175      747 Front Street
# 48         37.797435        -122.403175      747 Front Street
# 49         37.797435        -122.403175      747 Front Street
#
#    offices_address_2 offices_zip_code
# 0    275 Seventh Ave            10001  \
# 1    275 Seventh Ave            10001
# 2    275 Seventh Ave            10001
# 3    275 Seventh Ave            10001
# 4    275 Seventh Ave            10001
# 5    275 Seventh Ave            10001
# 6    275 Seventh Ave            10001
# 7    275 Seventh Ave            10001
# 8    275 Seventh Ave            10001
# 9    275 Seventh Ave            10001
# 10        11th Floor            10001
# 11        11th Floor            10001
# 12        11th Floor            10001
# 13        11th Floor            10001
# 14        11th Floor            10001
# 15        11th Floor            10001
# 16        11th Floor            10001
# 17        11th Floor            10001
# 18        11th Floor            10001
# 19        11th Floor            10001
# 20               NaN       10016-5602
# 21               NaN       10016-5602
# 22               NaN       10016-5602
# 23               NaN       10016-5602
# 24               NaN       10016-5602
# 25               NaN       10016-5602
# 26               NaN       10016-5602
# 27               NaN       10016-5602
# 28               NaN       10016-5602
# 29               NaN       10016-5602
# 30         3rd Floor            94111
# 31         3rd Floor            94111
# 32         3rd Floor            94111
# 33         3rd Floor            94111
# 34         3rd Floor            94111
# 35         3rd Floor            94111
# 36         3rd Floor            94111
# 37         3rd Floor            94111
# 38         3rd Floor            94111
# 39         3rd Floor            94111
# 40         2nd Floor            94111
# 41         2nd Floor            94111
# 42         2nd Floor            94111
# 43         2nd Floor            94111
# 44         2nd Floor            94111
# 45         2nd Floor            94111
# 46         2nd Floor            94111
# 47         2nd Floor            94111
# 48         2nd Floor            94111
# 49         2nd Floor            94111
#
#                                            vegan_rest  ...  num_preschool
# 0   [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3  \
# 1   [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3
# 2   [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3
# 3   [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3
# 4   [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3
# 5   [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3
# 6   [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3
# 7   [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3
# 8   [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3
# 9   [{'fsq_id': '5287e35711d2ab3ea77f7ebb', 'categ...  ...              3
# 10  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 11  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 12  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 13  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 14  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 15  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 16  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 17  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 18  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 19  [{'fsq_id': '5f161e6f978e663e91ab7155', 'categ...  ...              2
# 20  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 21  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 22  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 23  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 24  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 25  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 26  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 27  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 28  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 29  [{'fsq_id': '4b02f734f964a520814b22e3', 'categ...  ...              1
# 30  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 31  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 32  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 33  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 34  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 35  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 36  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 37  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 38  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 39  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              1
# 40  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
# 41  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
# 42  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
# 43  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
# 44  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
# 45  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
# 46  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
# 47  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
# 48  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
# 49  [{'fsq_id': '4b391baef964a520605625e3', 'categ...  ...              3
#
#                                             starbucks  num_starbucks
# 0   [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8  \
# 1   [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8
# 2   [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8
# 3   [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8
# 4   [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8
# 5   [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8
# 6   [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8
# 7   [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8
# 8   [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8
# 9   [{'fsq_id': '506c7556e4b03bdbe5afda50', 'categ...              8
# 10  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 11  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 12  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 13  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 14  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 15  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 16  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 17  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 18  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 19  [{'fsq_id': '55a555fd498e1727ae82a345', 'categ...             10
# 20  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 21  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 22  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 23  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 24  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 25  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 26  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 27  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 28  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 29  [{'fsq_id': '4aa01922f964a520483e20e3', 'categ...             10
# 30  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 31  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 32  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 33  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 34  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 35  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 36  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 37  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 38  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 39  [{'fsq_id': '6167c8968b400716f1d65e0b', 'categ...              7
# 40  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
# 41  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
# 42  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
# 43  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
# 44  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
# 45  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
# 46  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
# 47  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
# 48  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
# 49  [{'fsq_id': '49d0da91f964a520395b1fe3', 'categ...              3
#
#                                               airport  num_airport
# 0   [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10  \
# 1   [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10
# 2   [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10
# 3   [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10
# 4   [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10
# 5   [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10
# 6   [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10
# 7   [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10
# 8   [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10
# 9   [{'fsq_id': '4fd2219fe4b03e7cee27e882', 'categ...           10
# 10  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 11  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 12  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 13  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 14  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 15  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 16  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 17  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 18  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 19  [{'fsq_id': '4adb6119f964a520a72621e3', 'categ...           10
# 20  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 21  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 22  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 23  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 24  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 25  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 26  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 27  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 28  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 29  [{'fsq_id': '4a5623d5f964a52081b41fe3', 'categ...           10
# 30  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 31  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 32  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 33  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 34  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 35  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 36  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 37  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 38  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 39  [{'fsq_id': '535ece06498e564c67f2f049', 'categ...            9
# 40  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
# 41  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
# 42  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
# 43  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
# 44  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
# 45  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
# 46  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
# 47  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
# 48  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
# 49  [{'fsq_id': 'eb55470d48024203bb09894b', 'categ...            3
#
#                                                 clubs  num_clubs
# 0   [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10  \
# 1   [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10
# 2   [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10
# 3   [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10
# 4   [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10
# 5   [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10
# 6   [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10
# 7   [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10
# 8   [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10
# 9   [{'fsq_id': '60da36b2d61cae1ce8d45a04', 'categ...         10
# 10  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 11  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 12  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 13  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 14  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 15  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 16  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 17  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 18  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 19  [{'fsq_id': '4cc0b629f82ebfb7b4af6f91', 'categ...          8
# 20  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 21  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 22  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 23  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 24  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 25  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 26  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 27  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 28  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 29  [{'fsq_id': '741d73901e18012f487f54d8', 'categ...          4
# 30  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 31  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 32  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 33  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 34  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 35  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 36  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 37  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 38  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 39  [{'fsq_id': '4f32bd4d19836c91c7f53884', 'categ...          7
# 40  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
# 41  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
# 42  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
# 43  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
# 44  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
# 45  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
# 46  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
# 47  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
# 48  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
# 49  [{'fsq_id': '55ed1abb498e9e55d2e0edfc', 'categ...          9
#
#    weighted_punct  vegan_rest_lat  vegan_rest_lon
# 0          824.98       40.744946      -73.990249
# 1          824.98       40.743323      -73.994378
# 2          824.98       40.745153      -73.994538
# 3          824.98       40.746151      -73.997547
# 4          824.98       40.745543      -73.994073
# 5          824.98       40.745134      -73.995236
# 6          824.98       40.750153      -73.995215
# 7          824.98       40.747204      -73.996497
# 8          824.98       40.747313      -74.000432
# 9          824.98        40.74262      -73.996447
# 10         821.40       40.744946      -73.990249
# 11         821.40       40.743323      -73.994378
# 12         821.40       40.745153      -73.994538
# 13         821.40       40.746151      -73.997547
# 14         821.40       40.745543      -73.994073
# 15         821.40       40.745134      -73.995236
# 16         821.40       40.750153      -73.995215
# 17         821.40       40.747204      -73.996497
# 18         821.40       40.747313      -74.000432
# 19         821.40        40.74262      -73.996447
# 20         732.10       40.744946      -73.990249
# 21         732.10       40.743323      -73.994378
# 22         732.10       40.745153      -73.994538
# 23         732.10       40.746151      -73.997547
# 24         732.10       40.745543      -73.994073
# 25         732.10       40.745134      -73.995236
# 26         732.10       40.750153      -73.995215
# 27         732.10       40.747204      -73.996497
# 28         732.10       40.747313      -74.000432
# 29         732.10        40.74262      -73.996447
# 30         699.97       40.744946      -73.990249
# 31         699.97       40.743323      -73.994378
# 32         699.97       40.745153      -73.994538
# 33         699.97       40.746151      -73.997547
# 34         699.97       40.745543      -73.994073
# 35         699.97       40.745134      -73.995236
# 36         699.97       40.750153      -73.995215
# 37         699.97       40.747204      -73.996497
# 38         699.97       40.747313      -74.000432
# 39         699.97        40.74262      -73.996447
# 40         607.15       40.744946      -73.990249
# 41         607.15       40.743323      -73.994378
# 42         607.15       40.745153      -73.994538
# 43         607.15       40.746151      -73.997547
# 44         607.15       40.745543      -73.994073
# 45         607.15       40.745134      -73.995236
# 46         607.15       40.750153      -73.995215
# 47         607.15       40.747204      -73.996497
# 48         607.15       40.747313      -74.000432
# 49         607.15        40.74262      -73.996447
#
# [50 rows x 22 columns]

# %%
df_subset['vegan_rest_2'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vegan_rest_2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_subset['vegan_rest_2'][0]
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\core\frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'vegan_rest_2'

# %%
ast.literal_eval(df_subset['vegan_rest'][3])

# %%
p1_lat_NY, p1_lon_NY, p2_lat_NY, p2_lon_NY, p3_lat_NY, p3_lon_NY = df['offices_latitude'][0], df['offices_longitude'][0], df['offices_latitude'][1], df['offices_longitude'][1], df['offices_latitude'][2], df['offices_longitude'][2]

# %%
middle_lat_NY = median([p1_lat_NY, p2_lat_NY, p3_lat_NY])
middle_lon_NY = median([p1_lon_NY, p2_lon_NY, p3_lon_NY])

# %%
testmap_NY = folium.Map(location=[middle_lat_NY, middle_lon_NY], zoom_start=13)

# %%
folium.Circle(location=[p1_lat_NY, p1_lon_NY], popup='Point 1A', fill_color='#ff0000', radius=200, weight=2, color="#000000").add_to(testmap_NY)
folium.Circle(location=[p2_lat_NY, p2_lon_NY], popup='Point 1B', fill_color='#00ff00', radius=200, weight=2, color="#000000").add_to(testmap_NY)
folium.Circle(location=[p3_lat_NY, p3_lon_NY], popup='Point 1C', fill_color='#0000ff', radius=200, weight=2, color="#ffffff").add_to(testmap_NY)

# %%
display(testmap_NY)

# %%
for index, row in df.iterrows():
    
    all_together = {"location": [row["offices_latitude"], row["offices_longitude"]]}
            
    # 1. Check for the conditions of Festividad: to get the diferent Icon
    if row["num_vegan_rest"] != None:
        icon = Icon (
                icon = "laptop",
                prefix = "fa",
                color = "red",
                icon_color = "white")
        
    elif row["num_preschool"] != None:
        icon = Icon (
                icon = "moon-o",
                prefix = "fa",
                color = "white",
                icon_color = "black")
        
    elif row["num_starbucks"] != None:
        icon = Icon (
                icon = "cutlery",
                prefix = "fa",
                color = "green",
                icon_color = "white")
        
    elif row["num_airport"] != None:
        icon = Icon (
                icon = "cutlery",
                prefix = "fa",
                color = "green",
                icon_color = "white")
        
    elif row["num_clubs"] != None:
        icon = Icon (
                icon = "cutlery",
                prefix = "fa",
                color = "green",
                icon_color = "white")
    
    # 2. With the icon: I pass that to the Marker

    new_marker = Marker(**all_together, icon = icon)
    
    # 3. Add a Marker per row
    
    new_marker.add_to(testmap_NY)

testmap_NY

# %%
for index, row in df.iterrows():
    
    all_together = {"location": [row["offices_latitude"], row["offices_longitude"]]}
            
    # 1. Check for the conditions of Festividad: to get the diferent Icon
    if row["num_vegan_rest"] != None:
        icon = Icon (
                icon = "laptop",
                prefix = "fa",
                color = "red",
                icon_color = "white")
      
    # 2. With the icon: I pass that to the Marker

    new_marker = Marker(**all_together, icon = icon)
    
    # 3. Add a Marker per row
    
    new_marker.add_to(testmap_NY)

testmap_NY
